# %%
import pandas as pd

# %%
# 코스피 200 기업 뽑아내기

# %%
a="대림산업 대우건설 동양 삼성엔지니어링 쌍용양회 아이에스동서 한일홀딩스 한전기술 현대건설 GS건설 HDC HDC현대산업개발 KCC LG하우시스 기업은행 메리츠종금증권 미래에셋대우 삼성생명 삼성증권 삼성카드 삼성화재 신한지주 우리금융지주 하나금융지주 한국금융지주 한화생명 현대해상 BNK금융지주 DB손해보험 KB금융 NH투자증권 강원랜드 금호타이어 기아차 넥센타이어 대교 롯데쇼핑 롯데하이마트 만도 삼성물산 세방전지 신세계 쌍용차 에스엘 영원무역 코웨이 쿠쿠홀딩스 한국타이어 한국타이어월드와이드 한라홀딩스 한샘 한섬 한세실업 한온시스템 현대리바트 현대모비스 현대백화점 현대위아 현대차 현대홈쇼핑 호텔신라 GKL LF S&T모티브 SK네트웍스 대한항공 두산 에스원 팬오션 포스코대우 한국단자 한국항공우주 한전KPS 한화에어로스페이스 현대글로비스 CJ대한통운 LG상사 LIG넥스원 LS LS산전 남양유업 농심 대상 동서 동원F&B 락앤락 롯데지주 롯데칠성 롯데푸드 무학 빙그레 삼양사 삼양홀딩스 아모레G 아모레퍼시픽 오뚜기 오리온 오리온홀딩스 이마트 코스맥스 팜스코 하이트진로 한국가스공사 한국전력 한국콜마 현대그린푸드 BGF BGF리테일 CJ CJ제일제당 GS리테일 KT&G LG생활건강 SPC삼립 금호석유 남해화학 대한유화 롯데케미칼 롯데정밀화학 유니드 코오롱인더 태광산업 한국쉘석유 한솔케미칼 한화 한화케미칼 효성 효성중공업 후성 휴켐스 AK홀딩스 GS LG화학 OCI S-Oil SK SKC SK디스커버리 SK이노베이션 SK케미칼 대덕전자 삼성SDI 삼성SDS 삼성전기 삼성전자 일진머티리얼즈 DB하이텍 LG LG디스플레이 LG이노텍 SK하이닉스 대우조선해양 두산인프라코어 두산밥캣 두산중공업 삼성중공업 한진중공업 현대로템 현대미포조선 현대엘리베이터 현대중공업 현대중공업지주 고려아연 고려제강 동국제강 동원시스템즈 세아베스틸 영풍 풍산 현대제철 POSCO 넷마블 엔씨소프트 이노션 제일기획 카카오 CJ CGV KT LG유플러스 NAVER SBS SK텔레콤 녹십자 녹십자홀딩스 대웅제약 동아쏘시오홀딩스 동아에스티 보령제약 부광약품 삼성바이오로직스 셀트리온 영진약품 유한양행 일양약품 종근당 한미사이언스 한미약품 한올바이오파마 JW중외제약 JW홀딩스"
b =a.split(" ")
b
# Out:
# ['대림산업',
#  '대우건설',
#  '동양',
#  '삼성엔지니어링',
#  '쌍용양회',
#  '아이에스동서',
#  '한일홀딩스',
#  '한전기술',
#  '현대건설',
#  'GS건설',
#  'HDC',
#  'HDC현대산업개발',
#  'KCC',
#  'LG하우시스',
#  '기업은행',
#  '메리츠종금증권',
#  '미래에셋대우',
#  '삼성생명',
#  '삼성증권',
#  '삼성카드',
#  '삼성화재',
#  '신한지주',
#  '우리금융지주',
#  '하나금융지주',
#  '한국금융지주',
#  '한화생명',
#  '현대해상',
#  'BNK금융지주',
#  'DB손해보험',
#  'KB금융',
#  'NH투자증권',
#  '강원랜드',
#  '금호타이어',
#  '기아차',
#  '넥센타이어',
#  '대교',
#  '롯데쇼핑',
#  '롯데하이마트',
#  '만도',
#  '삼성물산',
#  '세방전지',
#  '신세계',
#  '쌍용차',
#  '에스엘',
#  '영원무역',
#  '코웨이',
#  '쿠쿠홀딩스',
#  '한국타이어',
#  '한국타이어월드와이드',
#  '한라홀딩스',
#  '한샘',
#  '한섬',
#  '한세실업',
#  '한온시스템',
#  '현대리바트',
#  '현대모비스',
#  '현대백화점',
#  '현대위아',
#  '현대차',
#  '현대홈쇼핑',
#  '호텔신라',
#  'GKL',
#  'LF',
#  'S&T모티브',
#  'SK네트웍스',
#  '대한항공',
#  '두산',
#  '에스원',
#  '팬오션',
#  '포스코대우',
#  '한국단자',
#  '한국항공우주',
#  '한전KPS',
#  '한화에어로스페이스',
#  '현대글로비스',
#  'CJ대한통운',
#  'LG상사',
#  'LIG넥스원',
#  'LS',
#  'LS산전',
#  '남양유업',
#  '농심',
#  '대상',
#  '동서',
#  '동원F&B',
#  '락앤락',
#  '롯데지주',
# ...

# %%
# 주가 자료 불러오기

# %%
df1 = pd.read_csv(r"C:\Users\deokju.DESKTOP-SSNCOJV\Desktop/주가.csv", engine='python')

# %%
df1.head(20)
# Out:
#    itemcode itemname market      date  close_val  change_val  change_rate  \
# 0      3280     흥아해운  KOSPI  20150107     2805.0       -45.0        -1.60
# 1      3280     흥아해운  KOSPI  20150113     2655.0       -25.0        -0.94
# 2      3280     흥아해운  KOSPI  20150116     2710.0       105.0         3.87
# 3      3280     흥아해운  KOSPI  20150119     2575.0      -135.0        -5.24
# 4      3280     흥아해운  KOSPI  20150122     2570.0       -35.0        -1.36
# 5      3280     흥아해운  KOSPI  20150128     2700.0        20.0         0.74
# 6      3280     흥아해운  KOSPI  20150203     2800.0        25.0         0.89
# 7      3280     흥아해운  KOSPI  20150206     2770.0       -20.0        -0.72
# 8      3280     흥아해운  KOSPI  20150209     2845.0        75.0         2.64
# 9      3280     흥아해운  KOSPI  20150212     2980.0        30.0         1.01
# 10     3280     흥아해운  KOSPI  20150224     2890.0       110.0         3.81
# 11     3280     흥아해운  KOSPI  20150227     2890.0       -10.0        -0.35
# ...

# %%
df=df1[df1['itemname'].isin(b)] # itemname 열에서 blist에 있는 회사만 출력(kospi200만 출력)

# %%
# null 값 확인

# %%
df.isnull().any()
# Out:
# itemcode       False
# itemname       False
# market         False
# date           False
# close_val       True
# change_val      True
# change_rate     True
# acc_quant       True
# market_sum      True
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60619 entries, 1292 to 270782
# Data columns (total 9 columns):
# itemcode       60619 non-null object
# itemname       60619 non-null object
# market         60619 non-null object
# date           60619 non-null int64
# close_val      60614 non-null float64
# change_val     57233 non-null float64
# change_rate    57233 non-null float64
# acc_quant      60376 non-null float64
# market_sum     60614 non-null float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 4.6+ MB

# %%
df = df.loc[ : ,'itemname':'change_rate']
df
# Out:
#        itemname market      date  close_val  change_val  change_rate
# 1292        휴켐스  KOSPI  20150107    25550.0      -200.0        -0.78
# 1293        휴켐스  KOSPI  20150113    25200.0     -1300.0        -5.16
# 1294        휴켐스  KOSPI  20150116    26800.0       350.0         1.31
# 1295        휴켐스  KOSPI  20150119    27050.0       250.0         0.92
# 1296        휴켐스  KOSPI  20150122    26800.0      -250.0        -0.93
# 1297        휴켐스  KOSPI  20150128    26650.0       150.0         0.56
# 1298        휴켐스  KOSPI  20150203    26100.0      -300.0        -1.15
# 1299        휴켐스  KOSPI  20150206    26200.0      -100.0        -0.38
# 1300        휴켐스  KOSPI  20150209    26100.0      -100.0        -0.38
# 1301        휴켐스  KOSPI  20150212    25900.0      -300.0        -1.16
# 1302        휴켐스  KOSPI  20150224    26100.0       300.0         1.15
# 1303        휴켐스  KOSPI  20150227    25650.0       150.0         0.58
# 1304        휴켐스  KOSPI  20150302    25400.0      -250.0        -0.98
# ...

# %%
# 정리 후 한번 저장

# %%
df.to_csv('out.csv')

# %%
man=pd.read_csv(r"C:\Users\deokju.DESKTOP-SSNCOJV\Desktop/out.csv", engine='python')
man.info()
man.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60619 entries, 0 to 60618
# Data columns (total 6 columns):
# itemname       59109 non-null object
# market         59109 non-null object
# date           59109 non-null float64
# close_val      59109 non-null float64
# change_val     55798 non-null float64
# change_rate    55798 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 2.8+ MB
#   itemname market        date  close_val  change_val  change_rate
# 0      휴켐스  KOSPI  20150107.0    25550.0      -200.0        -0.78
# 1      휴켐스  KOSPI  20150113.0    25200.0     -1300.0        -5.16
# 2      휴켐스  KOSPI  20150116.0    26800.0       350.0         1.31
# 3      휴켐스  KOSPI  20150119.0    27050.0       250.0         0.92
# 4      휴켐스  KOSPI  20150122.0    26800.0      -250.0        -0.93

# %%
# 주식 종목 별로 묶어서 같은 기간 동안 코스피200에 존재 했는지 확인

# %%
man.groupby("itemname").count()
man.groupby("itemname").count()[1:50]
man.groupby("itemname").count()[51:100]
man.groupby("itemname").count()[101:150]
man.groupby("itemname").count()[151:200]
t = ["BGF리테일","HDC현대산업개발","현대중공업지주","효성중공업","LIG넥스원","SK케미칼","넷마블","두산밥캣","이노션","삼성바이오로직스","오리온"]
# Out:
#            market  date  close_val  change_val  change_rate
# itemname
# AK홀딩스         323   323        323         310          310
# BGF           323   323        323         294          294
# BNK금융지주       323   323        323         300          300
# CJ            323   323        323         303          303
# CJ대한통운        323   323        323         291          291
# CJ제일제당        323   323        323         310          310
# DB손해보험        323   323        323         310          310
# DB하이텍         323   323        323         304          304
# GKL           323   323        323         303          303
# GS            323   323        323         309          309
# GS건설          323   323        323         309          309
# GS리테일         323   323        323         307          307
# HDC           323   323        323         298          298
# JW중외제약        323   323        323         310          310
# ...

# %%
df=df.drop(("BGF리테일","HDC현대산업개발","현대중공업지주","효성중공업","LIG넥스원","SK케미칼","넷마블","두산밥캣","이노션")
# Out:
#   File "<ipython-input-193-bf7ab3e79bbb>", line 1
#     df=df.drop(("BGF리테일","HDC현대산업개발","현대중공업지주","효성중공업","LIG넥스원","SK케미칼","넷마블","두산밥캣","이노션")
#                                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
# change_rate 100씩 더해 기하평균 가능하게 만들기

# %%
man["change_rate +100"] = man["change_rate"] + 100

# %%
man3=pd.read_csv(r"C:\Users\deokju.DESKTOP-SSNCOJV\Desktop/out2.csv", engine='python')

# %%
man3
# Out:
#       itemname market      date  close_val    change_val  change_rate  \
# 0        AK홀딩스  KOSPI  20150107      86600  -2000.000000    -2.310000
# 1        AK홀딩스  KOSPI  20150113      88000  -1000.000000    -1.140000
# 2        AK홀딩스  KOSPI  20150116      92300    300.000000     0.330000
# 3        AK홀딩스  KOSPI  20150119      88200  -4100.000000    -4.650000
# 4        AK홀딩스  KOSPI  20150122      90300  -1000.000000    -1.110000
# 5        AK홀딩스  KOSPI  20150128      92400   -100.000000    -0.110000
# 6        AK홀딩스  KOSPI  20150203      98000    -34.516129    -0.050871
# 7        AK홀딩스  KOSPI  20150206      91700  -1700.000000    -1.850000
# 8        AK홀딩스  KOSPI  20150209      86000  -5700.000000    -6.630000
# 9        AK홀딩스  KOSPI  20150212      91500   1600.000000     1.750000
# 10       AK홀딩스  KOSPI  20150224      99800  12000.000000    12.020000
# 11       AK홀딩스  KOSPI  20150227     101000    500.000000     0.500000
# ...

# %%
# 코스피200을 종목 별로 묶기

# %%
one=['대림산업',
 '대우건설',
 '동양',
 '삼성엔지니어링',
 '쌍용양회',
 '아이에스동서',
 '한일홀딩스',
 '한전기술',
 '현대건설',
 'GS건설',
 'HDC',
 'HDC현대산업개발',
 'KCC',
 'LG하우시스']
two=['기업은행',
 '메리츠종금증권',
 '미래에셋대우',
 '삼성생명',
 '삼성증권',
 '삼성카드',
 '삼성화재',
 '신한지주',
 '우리금융지주',
 '하나금융지주',
 '한국금융지주',
 '한화생명',
 '현대해상',
 'BNK금융지주',
 'DB손해보험',
 'KB금융',
 'NH투자증권',
]
three=[ '강원랜드',
 '금호타이어',
 '기아차',
 '넥센타이어',
 '대교',
 '롯데쇼핑',
 '롯데하이마트',
 '만도',
 '삼성물산',
 '세방전지',
 '신세계',
 '쌍용차',
 '에스엘',
 '영원무역',
 '코웨이',
 '쿠쿠홀딩스',
 '한국타이어',
 '한국타이어월드와이드',
 '한라홀딩스',
 '한샘',
 '한섬',
 '한세실업',
 '한온시스템',
 '현대리바트',
 '현대모비스',
 '현대백화점',
 '현대위아',
 '현대차',
 '현대홈쇼핑',
 '호텔신라',
 'GKL',
 'LF',
 'S&T모티브',
 'SK네트웍스']
four=['대한항공',
 '두산',
 '에스원',
 '팬오션',
 '포스코대우',
 '한국단자',
 '한국항공우주',
 '한전KPS',
 '한화에어로스페이스',
 '현대글로비스',
 'CJ대한통운',
 'LG상사',
 'LIG넥스원',
 'LS',
 'LS산전']
five=[ '남양유업',
 '농심',
 '대상',
 '동서',
 '동원F&B',
 '락앤락',
 '롯데지주',
 '롯데칠성',
 '롯데푸드',
 '무학',
 '빙그레',
 '삼양사',
 '삼양홀딩스',
 '아모레G',
 '아모레퍼시픽',
 '오뚜기',
 '오리온',
 '오리온홀딩스',
 '이마트',
 '코스맥스',
 '팜스코',
 '하이트진로',
 '한국가스공사',
 '한국전력',
 '한국콜마',
 '현대그린푸드',
 'BGF',
 'BGF리테일',
 'CJ',
 'CJ제일제당',
 'GS리테일',
 'KT&G',
 'LG생활건강',
 'SPC삼립']
six =[ '금호석유',
 '남해화학',
 '대한유화',
 '롯데케미칼',
 '롯데정밀화학',
 '유니드',
 '코오롱인더',
 '태광산업',
 '한국쉘석유',
 '한솔케미칼',
 '한화',
 '한화케미칼',
 '효성',
 '효성중공업',
 '후성',
 '휴켐스',
 'AK홀딩스',
 'GS',
 'LG화학',
 'OCI',
 'S-Oil',
 'SK',
 'SKC',
 'SK디스커버리',
 'SK이노베이션',
 'SK케미칼']
seven=['대덕전자',
 '삼성SDI',
 '삼성SDS',
 '삼성전기',
 '삼성전자',
 '일진머티리얼즈',
 'DB하이텍',
 'LG',
 'LG디스플레이',
 'LG이노텍',
 'SK하이닉스']
eight=['대우조선해양',
 '두산인프라코어',
 '두산밥캣',
 '두산중공업',
 '삼성중공업',
 '한진중공업',
 '현대로템',
 '현대미포조선',
 '현대엘리베이터',
 '현대중공업',
 '현대중공업지주']
nine=['고려아연',
 '고려제강',
 '동국제강',
 '동원시스템즈',
 '세아베스틸',
 '영풍',
 '풍산',
 '현대제철',
 'POSCO']
ten = ['넷마블',
 '엔씨소프트',
 '이노션',
 '제일기획',
 '카카오',
 'CJ',
 'CGV',
 'KT',
 'LG유플러스',
 'NAVER',
 'SBS',
 'SK텔레콤']
ele=['녹십자',
 '녹십자홀딩스',
 '대웅제약',
 '동아쏘시오홀딩스',
 '동아에스티',
 '보령제약',
 '부광약품',
 '삼성바이오로직스',
 '셀트리온',
 '영진약품',
 '유한양행',
 '일양약품',
 '종근당',
 '한미사이언스',
 '한미약품',
 '한올바이오파마',
 'JW중외제약',
 'JW홀딩스']

# %%
x1=man3[man3['itemname'].isin(one)]
x2=man3[man3['itemname'].isin(two)]
x3=man3[man3['itemname'].isin(three)]
x4=man3[man3['itemname'].isin(four)]
x5=man3[man3['itemname'].isin(five)]
x6=man3[man3['itemname'].isin(six)]
x7=man3[man3['itemname'].isin(seven)]
x8=man3[man3['itemname'].isin(eight)]
x9=man3[man3['itemname'].isin(nine)]
x10=man3[man3['itemname'].isin(ten)]
x11=man3[man3['itemname'].isin(ele)]

# %%
# 기하평균

# %%
gmean_1=x1.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_2=x2.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_3=x3.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_4=x4.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_5=x5.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_6=x6.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_7=x7.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_8=x8.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_9=x9.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_10=x10.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100
gmean_11=x11.groupby('date')["change_rate +100"].apply(lambda group: group.product() ** (1 / float(len(group))))-100

# %%
product.to_csv('finally.csv')
